# %%
import requests
import pandas as pd
import json

# %%
url = "https://free-nba.p.rapidapi.com/stats?seasons[]=2020"

querystring = {"page":"0","per_page":"100"}

headers = {'x-rapidapi-host': "free-nba.p.rapidapi.com",
    'x-rapidapi-key': "0a58c448e1msh42682201a62cc30p1ea6c2jsnb4992c5a1579"}

response = requests.get(url, headers=headers, params=querystring)

print(response.text[-80:])
# Out:
# l_pages":317,"current_page":1,"next_page":2,"per_page":100,"total_count":31657}}

# %%
stl = []
dreb = []
first_name=[]
last_name=[]

for i in range(318):

    url = "https://free-nba.p.rapidapi.com/stats?seasons[]=2020"

    querystring = {"page":"{i}","per_page":"100"}

    headers = {'x-rapidapi-host': "free-nba.p.rapidapi.com",
               'x-rapidapi-key': "0a58c448e1msh42682201a62cc30p1ea6c2jsnb4992c5a1579"}

    result = requests.get(url, headers=headers, params=querystring)
    
    data = result.json()
    
    for i in range(len(data['data'])):
        
        stl.append(data['data'][i]['stl'])
        
        dreb.append(data['data'][i]['dreb'])
        
        first_name.append(data['data'][i]['player']['first_name'])
        
        last_name.append(data['data'][i]['player']['last_name'])

# %%
df = pd.DataFrame(list(zip(first_name, last_name,stl,dreb)),
               columns =['First Name', 'Last Name','STL','DREB'])

# %%
df['Player']=df['First Name']+' '+ df['Last Name']

# %%
df=df[['Player','STL','DREB']]
df
# Out:
#                         Player  STL  DREB
# 0                 Kevin Durant    3     4
# 1                   Jeff Green    1     0
# 2               DeAndre Jordan    1     9
# 3                Stephen Curry    2     1
# 4                 Kyrie Irving    0     3
# ...                        ...  ...   ...
# 31795            Terrence Ross    2     2
# 31796            Evan Fournier    2     4
# 31797  Michael Carter-Williams    0     1
# 31798                Raul Neto    0     0
# 31799               Khem Birch    0     5
#
# [31800 rows x 3 columns]

# %%
kagle = pd.read_csv('all_seasons_2.csv')

# %%
kagledf = pd.DataFrame(kagle)

# %%
kagledf
# Out:
#        Unnamed: 0          player_name team_abbreviation   age  player_height  \
# 0               0        Travis Knight               LAL  22.0         213.36
# 1               1            Matt Fish               MIA  27.0         210.82
# 2               2         Matt Bullard               HOU  30.0         208.28
# 3               3         Marty Conlon               BOS  29.0         210.82
# 4               4      Martin Muursepp               DAL  22.0         205.74
# ...           ...                  ...               ...   ...            ...
# 11695       11695  Matthew Dellavedova               CLE  30.0         190.50
# 11696       11696     Maurice Harkless               SAC  28.0         200.66
# 11697       11697            Max Strus               MIA  25.0         195.58
# 11698       11698    Marcus Morris Sr.               LAC  31.0         203.20
# 11699       11699         Aaron Gordon               DEN  25.0         203.20
#
#        player_weight                          college    country draft_year  \
# 0         106.594120                      Connecticut        USA       1996
# 1         106.594120        North Carolina-Wilmington        USA       1992
# 2         106.594120                             Iowa        USA  Undrafted
# 3         111.130040                       Providence        USA  Undrafted
# 4         106.594120                             None        USA       1996
# ...              ...                              ...        ...        ...
# 11695      90.718400  St.Mary's College of California  Australia  Undrafted
# 11696      99.790240                       St. John's        USA       2012
# 11697      97.522280                           DePaul        USA  Undrafted
# 11698      98.883056                           Kansas        USA       2011
# 11699     106.594120                          Arizona        USA       2014
#
#       draft_round  ...   pts  reb  ast  net_rating  oreb_pct  dreb_pct  \
# 0               1  ...   4.8  4.5  0.5         6.2     0.127     0.182
# 1               2  ...   0.3  0.8  0.0       -15.1     0.143     0.267
# 2       Undrafted  ...   4.5  1.6  0.9         0.9     0.016     0.115
# 3       Undrafted  ...   7.8  4.4  1.4        -9.0     0.083     0.152
# 4               1  ...   3.7  1.6  0.5       -14.5     0.109     0.118
# ...           ...  ...   ...  ...  ...         ...       ...       ...
# 11695   Undrafted  ...   2.8  1.8  4.5        -3.1     0.029     0.085
# 11696           1  ...   5.2  2.4  1.2        -2.9     0.017     0.097
# 11697   Undrafted  ...   6.1  1.1  0.6        -4.2     0.011     0.073
# 11698           1  ...  13.4  4.1  1.0         4.2     0.025     0.133
# 11699           1  ...  12.4  5.7  3.2         2.1     0.055     0.150
#
#        usg_pct  ts_pct  ast_pct   season
# 0        0.142   0.536    0.052  1996-97
# 1        0.265   0.333    0.000  1996-97
# 2        0.151   0.535    0.099  1996-97
# 3        0.167   0.542    0.101  1996-97
# 4        0.233   0.482    0.114  1996-97
# ...        ...     ...      ...      ...
# 11695    0.125   0.312    0.337  2020-21
# 11696    0.114   0.527    0.071  2020-21
# 11697    0.179   0.597    0.074  2020-21
# 11698    0.194   0.614    0.056  2020-21
# 11699    0.204   0.547    0.165  2020-21
#
# [11700 rows x 22 columns]

# %%
kagledf=kagledf[['player_name','team_abbreviation','age','player_height','country','pts','reb','ast','season']]
kagledf
# Out:
#                player_name team_abbreviation   age  player_height    country  \
# 0            Travis Knight               LAL  22.0         213.36        USA
# 1                Matt Fish               MIA  27.0         210.82        USA
# 2             Matt Bullard               HOU  30.0         208.28        USA
# 3             Marty Conlon               BOS  29.0         210.82        USA
# 4          Martin Muursepp               DAL  22.0         205.74        USA
# ...                    ...               ...   ...            ...        ...
# 11695  Matthew Dellavedova               CLE  30.0         190.50  Australia
# 11696     Maurice Harkless               SAC  28.0         200.66        USA
# 11697            Max Strus               MIA  25.0         195.58        USA
# 11698    Marcus Morris Sr.               LAC  31.0         203.20        USA
# 11699         Aaron Gordon               DEN  25.0         203.20        USA
#
#         pts  reb  ast   season
# 0       4.8  4.5  0.5  1996-97
# 1       0.3  0.8  0.0  1996-97
# 2       4.5  1.6  0.9  1996-97
# 3       7.8  4.4  1.4  1996-97
# 4       3.7  1.6  0.5  1996-97
# ...     ...  ...  ...      ...
# 11695   2.8  1.8  4.5  2020-21
# 11696   5.2  2.4  1.2  2020-21
# 11697   6.1  1.1  0.6  2020-21
# 11698  13.4  4.1  1.0  2020-21
# 11699  12.4  5.7  3.2  2020-21
#
# [11700 rows x 9 columns]

# %%
kagledf = kagledf[kagledf.season == '2020-21']
kagledf
# Out:
#                player_name team_abbreviation   age  player_height    country  \
# 11160         Yogi Ferrell               LAC  28.0         182.88        USA
# 11161      Zion Williamson               NOP  20.0         200.66        USA
# 11162           Zeke Nnaji               DEN  20.0         205.74        USA
# 11163          Zach LaVine               CHI  26.0         195.58        USA
# 11164        Yuta Watanabe               TOR  26.0         205.74      Japan
# ...                    ...               ...   ...            ...        ...
# 11695  Matthew Dellavedova               CLE  30.0         190.50  Australia
# 11696     Maurice Harkless               SAC  28.0         200.66        USA
# 11697            Max Strus               MIA  25.0         195.58        USA
# 11698    Marcus Morris Sr.               LAC  31.0         203.20        USA
# 11699         Aaron Gordon               DEN  25.0         203.20        USA
#
#         pts  reb  ast   season
# 11160   5.6  1.9  2.2  2020-21
# 11161  27.0  7.2  3.7  2020-21
# 11162   3.2  1.5  0.2  2020-21
# 11163  27.4  5.0  4.9  2020-21
# 11164   4.4  3.2  0.8  2020-21
# ...     ...  ...  ...      ...
# 11695   2.8  1.8  4.5  2020-21
# 11696   5.2  2.4  1.2  2020-21
# 11697   6.1  1.1  0.6  2020-21
# 11698  13.4  4.1  1.0  2020-21
# 11699  12.4  5.7  3.2  2020-21
#
# [540 rows x 9 columns]

# %%
final=pd.merge(kagledf,df,how='inner',left_on='player_name',right_on='Player')

# %%
final=pd.merge(kagledf,df,how='inner',left_on='player_name',right_on='Player')

# %%
final=final[['Player','team_abbreviation','age','player_height','country','pts','reb','ast','STL','DREB','season']]

# %%
final.drop_duplicates()
# Out:
#                  Player team_abbreviation   age  player_height   country  \
# 0       Zion Williamson               NOP  20.0         200.66       USA
# 318        Goran Dragic               MIA  35.0         190.50  Slovenia
# 636      Devontae Cacok               LAL  24.0         200.66       USA
# 954     Duncan Robinson               MIA  27.0         200.66       USA
# 1272       Eric Bledsoe               NOP  31.0         185.42       USA
# ...                 ...               ...   ...            ...       ...
# 29892      LeBron James               LAL  36.0         205.74       USA
# 30210        Marc Gasol               LAL  36.0         210.82     Spain
# 30528   Markieff Morris               LAL  31.0         205.74       USA
# 30846   Marquese Chriss               GSW  23.0         205.74       USA
# 31164  Maurice Harkless               SAC  28.0         200.66       USA
#
#         pts  reb  ast  STL  DREB   season
# 0      27.0  7.2  3.7    1    10  2020-21
# 318    13.4  3.4  4.4    4     2  2020-21
# 636     2.0  1.6  0.1    0     0  2020-21
# 954    13.1  3.5  1.8    0     5  2020-21
# 1272   12.2  3.4  3.8    1     2  2020-21
# ...     ...  ...  ...  ...   ...      ...
# 29892  25.0  7.7  7.8    0     3  2020-21
# 30210   5.0  4.1  2.1    0     1  2020-21
# 30528   6.7  4.4  1.2    0     3  2020-21
# 30846   6.5  6.5  1.0    0     5  2020-21
# 31164   5.2  2.4  1.2    0     2  2020-21
#
# [99 rows x 11 columns]
